# %% [markdown]
# Imports and install packages

# %%
# !pip3 install -q --upgrade pip
# !pip3 install -q pandas matplotlib seaborn openpyxl climateserv requests

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import climateserv.api

# %%
def read_well_data(csv_file: str) -> pd.DataFrame:
    """
    Read well data from a CSV file.

    Parameters:
    csv_file (str): The path to the CSV file.

    Returns:
    pd.DataFrame: DataFrame containing well data.
    """
    return pd.read_csv(csv_file)

def get_precipitation_average(lat: float, lon: float, start_date: str, end_date: str) -> float:
    """
    Get the precipitation average for a given latitude and longitude using ClimateSERV API.

    Parameters:
    lat (float): Latitude.
    lon (float): Longitude.
    start_date (str): Start date in MM/DD/YYYY format.
    end_date (str): End date in MM/DD/YYYY format.

    Returns:
    float: Precipitation average.
    """
    geometry_coords = [[lon - 0.01, lat + 0.01], [lon + 0.01, lat + 0.01],
                       [lon + 0.01, lat - 0.01], [lon - 0.01, lat - 0.01], [lon - 0.01, lat + 0.01]]
    dataset_type = 'IMERG'  # Change as per your requirement
    operation_type = 'Average'
    seasonal_ensemble = ''
    seasonal_variable = ''
    outfile = 'memory_object'

    # Updated to use positional arguments instead of keywords
    data = climateserv.api.request_data(dataset_type, operation_type, 
                                        start_date, end_date, 
                                        geometry_coords, 
                                        seasonal_ensemble, 
                                        seasonal_variable, outfile)
    return data

def main():
    wells_df = read_well_data(csv_file='../igrac/wells_df.csv')
    start_date = '01/01/2015'
    end_date = '12/31/2022'
    precip_avgs = []

    for index, row in wells_df.iterrows():
        avg_precip = get_precipitation_average(lat=row['Latitude'], lon=row['Longitude'], 
                                               start_date=start_date, end_date=end_date)
        precip_avgs.append(avg_precip)

    wells_df['Precipitation_Average'] = precip_avgs
    wells_df.to_csv('wells_with_precipitation.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
# New Script Run
# About to process scripted job item now.
# New Job Submitted to the Server: New JobID: 78739158-c04f-4387-98af-30acda63b004
# <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
# get_JobProgressValue_FromResponse: Something went wrong..Generic Catch All Error. 'NoneType' object is not subscriptable
# Current Job Progress: -1.  JobID: 78739158-c04f-4387-98af-30acda63b004
# Result of Job Status Cycle: error_generic
# Job, 78739158-c04f-4387-98af-30acda63b004 is done, did it succeed? : False
# ERROR.  There was an error with this job.
# (The error may have been caused by an error on the server.)
# Double check the parameters you set and try again.  If the error persists, please contact the ClimateSERV Staff and be sure to send the parameters you used. Thank you!
# ERROR.  There was an error with this job.
# (The error may have been caused by an error on the server.)
# Double check the parameters you set and try again.  If the error persists, please contact the ClimateSERV Staff and be sure to send the parameters you used. Thank you!
# =======================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb Cell 5 line 5
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=53'>54</a>     wells_df.to_csv('wells_with_precipitation.csv', index=False)
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=55'>56</a> if __name__ == "__main__":
# ---> <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=56'>57</a>     main()
#
# /Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb Cell 5 line 4
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=45'>46</a> precip_avgs = []
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=47'>48</a> for index, row in wells_df.iterrows():
# ---> <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=48'>49</a>     avg_precip = get_precipitation_average(lat=row['Latitude'], lon=row['Longitude'],
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=49'>50</a>                                            start_date=start_date, end_date=end_date)
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=50'>51</a>     precip_avgs.append(avg_precip)
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=52'>53</a> wells_df['Precipitation_Average'] = precip_avgs
#
# /Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a> outfile = 'memory_object'
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=33'>34</a> # Updated to use positional arguments instead of keywords
# ---> <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=34'>35</a> data = climateserv.api.request_data(dataset_type, operation_type,
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a>                                     start_date, end_date,
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a>                                     geometry_coords,
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>                                     seasonal_ensemble,
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=38'>39</a>                                     seasonal_variable, outfile)
#      <a href='vscode-notebook-cell:/Users/franciscofurey/00DataScience/fuegos/climateserv-test/climateserv_test_fran.ipynb#W2sZmlsZQ%3D%3D?line=39'>40</a> return data
#
# File ~/00DataScience/OpenAi/venv/lib/python3.9/site-packages/climateserv/api.py:383, in request_data(data_set_type, operation_type, earliest_date, latest_date, geometry_coords, seasonal_ensemble, seasonal_variable, outfile)
#     381             return
#     382 elif str(request_config['outfile']) == "memory_object":
# --> 383     return job_data[0]['JobReturnData']['JobData_ServerResponse_JSON']
#     384 else:
#     385     try:
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import requests

def test_ssl_certificates():
    """Test SSL certificates by making an HTTPS request."""
    test_url = 'https://www.google.com'  # A simple test URL
    try:
        response = requests.get(test_url)
        print(f"Success: Response code {response.status_code}")
    except requests.exceptions.SSLError as e:
        print(f"SSL Error: {e}")
    except Exception as e:
        print(f"Error: {e}")

if __name__ == "__main__":
    test_ssl_certificates()
# Out:
# Success: Response code 200
