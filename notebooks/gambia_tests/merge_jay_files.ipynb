# %%
# !pip3 install -q --upgrade pip
# !pip3 install -q pandas numpy matplotlib seaborn openpyxl climateserv requests netCDF4 xarray pyproj geopandas

# %%
import os
import sys
import numpy as np
import xarray as xr
import pandas as pd
import netCDF4 as nc
import geopandas as gpd
from pathlib import Path
from scipy.spatial import KDTree
from shapely.geometry import Point
# Calculate the path to the scripts folder relative to the current notebook.
scripts_dir = Path("../../").resolve()

# Add the scripts directory to the sys.path if it's not already there.
if str(scripts_dir) not in sys.path:
    sys.path.append(str(scripts_dir))

# %%
def analyze_nasadem_file(file_path: str) -> None:
    """
    Analyze a NASADEM NetCDF file and print out its contents, such as variable names,
    dimensions, and min/max values for longitude and latitude.

    Args:
    file_path (str): The path to the NASADEM NetCDF file.
    """
    # Open the NetCDF file
    dataset = nc.Dataset(file_path, 'r')

    # Print general information about the file
    print('##################################################')
    print(f"Analyzing file: {file_path}")
    print("Variables in this file:")
    for var in dataset.variables:
        print(f" - {var}: {dataset.variables[var].dimensions}, {dataset.variables[var].shape}")

    # Check for common variables like longitude and latitude
    if 'lon' in dataset.variables and 'lat' in dataset.variables:
        lon = dataset.variables['lon'][:]
        lat = dataset.variables['lat'][:]
        print(f"Longitude range: {np.min(lon)} to {np.max(lon)}")
        print(f"Latitude range: {np.min(lat)} to {np.max(lat)}")
    
    # Close the dataset
    dataset.close()

# Paths to your files
file_paths = [
    '../../data/original_data/jay_files/Topography_Products/Curvature.nc',
    '../../data/original_data/jay_files/Topography_Products/Drainage_Density.nc',
    '../../data/original_data/jay_files/Topography_Products/Slope.nc',
    '../../data/original_data/jay_files/hydrogeology.nc'
]

# Analyze each file
for path in file_paths:
    analyze_nasadem_file(file_path=path)
# Out:
# ##################################################
# Analyzing file: ../../data/original_data/jay_files/Topography_Products/Curvature.nc
# Variables in this file:
#  - lon: ('lon',), (11915,)
#  - lat: ('lat',), (2872,)
#  - Curvatu_tif2: ('lat', 'lon'), (2872, 11915)
# Longitude range: -17.078611111124776 to -13.769166666697293
# Latitude range: 13.077222222232688 to 13.874722222230263
# ##################################################
# Analyzing file: ../../data/original_data/jay_files/Topography_Products/Drainage_Density.nc
# Variables in this file:
#  - lon: ('lon',), (10937,)
#  - lat: ('lat',), (2873,)
#  - Drainage_density: ('lat', 'lon'), (2873, 10937)
# Longitude range: -16.806781756020996 to -13.769003978257615
# Latitude range: 13.077083333343863 to 13.874861111119214
# ##################################################
# Analyzing file: ../../data/original_data/jay_files/Topography_Products/Slope.nc
# Variables in this file:
#  - lon: ('lon',), (11915,)
#  - lat: ('lat',), (2872,)
#  - Slope_tif2: ('lat', 'lon'), (2872, 11915)
# Longitude range: -17.078611111124776 to -13.769166666697293
# Latitude range: 13.077222222232688 to 13.874722222230263
# ##################################################
# Analyzing file: ../../data/original_data/jay_files/hydrogeology.nc
# Variables in this file:
#  - lon: ('lon',), (247,)
#  - lat: ('lat',), (535,)
#  - Hydrogeo: ('lat', 'lon'), (535, 247)
# Longitude range: -17.52524 to -12.605240000000105
# Latitude range: 10.93111200000023 to 21.611112000000002

# %%
import xarray as xr
import pandas as pd

def nc_to_dataframe(file_path: str, var_name: str, dataset_name: str) -> pd.DataFrame:
    """
    Convert a NetCDF file to a pandas DataFrame and print the percentage of NaN values for the specified variable.

    Args:
    file_path (str): Path to the .nc file.
    var_name (str): Name of the variable in the .nc file to convert.
    dataset_name (str): Descriptive name for the dataset.

    Returns:
    pd.DataFrame: DataFrame representation of the NetCDF variable.
    """
    # Open the .nc file
    ds = xr.open_dataset(file_path)

    # Select the variable
    data = ds[var_name]

    # Convert to DataFrame
    df = data.to_dataframe().reset_index()

    # Calculate and print the percentage of NaN values
    nan_percentage = df[var_name].isna().mean() * 100
    print(f"DataFrame from {file_path} - Variable: {var_name}")
    print(df.head())  # Display the first few rows of the DataFrame
    print(f"Percentage of NaN values in '{var_name}': {nan_percentage:.2f}%")
    print('-' * 50)  # Separator

    # Store the DataFrame in a global variable
    globals()[f'df_{dataset_name}'] = df

# File paths, variable names, and dataset names
file_var_pairs = [
    ('../../data/original_data/jay_files/Topography_Products/Curvature.nc', 'Curvatu_tif2', 'curvature'),
    ('../../data/original_data/jay_files/Topography_Products/Drainage_Density.nc', 'Drainage_density', 'drainage_density'),
    ('../../data/original_data/jay_files/Topography_Products/Slope.nc', 'Slope_tif2', 'slope'),
    ('../../data/original_data/jay_files/hydrogeology.nc', 'Hydrogeo', 'Hydrogeology')
]

# Process each file
for file_path, var_name, dataset_name in file_var_pairs:
    nc_to_dataframe(file_path=file_path, var_name=var_name, dataset_name=dataset_name)

# After running this script, you can access each DataFrame directly, e.g., df_ndvi, df_ndwi, etc.
# Out:
# DataFrame from ../../data/original_data/jay_files/Topography_Products/Curvature.nc - Variable: Curvatu_tif2
#          lat        lon  Curvatu_tif2
# 0  13.874722 -17.078611           NaN
# 1  13.874722 -17.078333           NaN
# 2  13.874722 -17.078056           NaN
# 3  13.874722 -17.077778           NaN
# 4  13.874722 -17.077500           NaN
# Percentage of NaN values in 'Curvatu_tif2': 2.38%
# --------------------------------------------------
# DataFrame from ../../data/original_data/jay_files/Topography_Products/Drainage_Density.nc - Variable: Drainage_density
#          lat        lon  Drainage_density
# 0  13.874861 -16.806782               0.0
# 1  13.874861 -16.806504               0.0
# 2  13.874861 -16.806226               0.0
# 3  13.874861 -16.805948               0.0
# 4  13.874861 -16.805671               0.0
# Percentage of NaN values in 'Drainage_density': 0.00%
# --------------------------------------------------
# DataFrame from ../../data/original_data/jay_files/Topography_Products/Slope.nc - Variable: Slope_tif2
#          lat        lon  Slope_tif2
# 0  13.874722 -17.078611         NaN
# 1  13.874722 -17.078333         NaN
# 2  13.874722 -17.078056         NaN
# 3  13.874722 -17.077778         NaN
# 4  13.874722 -17.077500         NaN
# Percentage of NaN values in 'Slope_tif2': 2.46%
# --------------------------------------------------
# DataFrame from ../../data/original_data/jay_files/hydrogeology.nc - Variable: Hydrogeo
#          lat       lon  Hydrogeo
# 0  21.611112 -17.52524       NaN
# 1  21.611112 -17.50524       NaN
# 2  21.611112 -17.48524       NaN
# 3  21.611112 -17.46524       NaN
# 4  21.611112 -17.44524       NaN
# Percentage of NaN values in 'Hydrogeo': 51.56%
# --------------------------------------------------

# %%
df = pd.read_csv("../../data/final_dataset/original/gambia_lat_and_long.csv")
df
# Out:
#            long        lat
# 0    -16.670616  13.488346
# 1    -16.665998  13.488376
# 2    -16.684438  13.483734
# 3    -16.679820  13.483765
# 4    -16.675202  13.483796
# ...         ...        ...
# 2869 -16.746177  13.076569
# 2870 -16.741567  13.076600
# 2871 -16.736957  13.076631
# 2872 -16.732347  13.076662
# 2873 -16.727737  13.076693
#
# [2874 rows x 2 columns]

# %%
df_drainage_density
# Out:
#                 lat        lon  Drainage_density
# 0         13.874861 -16.806782          0.000000
# 1         13.874861 -16.806504          0.000000
# 2         13.874861 -16.806226          0.000000
# 3         13.874861 -16.805948          0.000000
# 4         13.874861 -16.805671          0.000000
# ...             ...        ...               ...
# 31421996  13.077083 -13.770115         10.032833
# 31421997  13.077083 -13.769837         10.017525
# 31421998  13.077083 -13.769560          9.998237
# 31421999  13.077083 -13.769282          9.974904
# 31422000  13.077083 -13.769004          9.947452
#
# [31422001 rows x 3 columns]

# %%
from scipy.spatial import KDTree
import pandas as pd

def find_nearest_drainage_density(df_wells: pd.DataFrame, df_drainage_density: pd.DataFrame) -> pd.DataFrame:
    """
    Encuentra el vecino más cercano en df_drainage_density para cada punto en df_wells
    y combina los datos, incluyendo solamente la columna Drainage_density.
    """
    # Verifica que las columnas estén correctamente nombradas y alineadas
    assert 'lat' in df_wells and 'long' in df_wells, "Las columnas 'lat' y 'long' deben estar en df_wells"
    assert 'lat' in df_drainage_density and 'lon' in df_drainage_density, "Las columnas 'lat' y 'lon' deben estar en df_drainage_density"

    # Construir KDTree para búsqueda eficiente del vecino más cercano
    tree = KDTree(df_drainage_density[['lat', 'lon']])

    # Lista para almacenar las filas combinadas
    merged_rows = []

    # Iterar sobre cada fila en df_wells
    for index, well in df_wells.iterrows():
        print(f"Analizando fila {index + 1}/{len(df_wells)}")

        # Encontrar el vecino más cercano para esta fila
        distance, nearest_idx = tree.query([well['lat'], well['long']], k=1)
        nearest_row = df_drainage_density.iloc[nearest_idx]

        print(f"Coincidencia más cercana encontrada en el índice {nearest_idx}: {nearest_row['Drainage_density']}")

        # Combinar los datos, incluyendo solamente Drainage_density
        merged_row = well.to_dict()
        merged_row['Drainage_density'] = nearest_row['Drainage_density']
        merged_rows.append(merged_row)

        print(f"Datos combinados: {merged_row}\n")
        
    merged_df = pd.DataFrame(merged_rows)

    # Devolver el DataFrame resultante
    return merged_df



def save_data(merged_df: pd.DataFrame, save_path: str) -> None:
    """Save the merged data to a CSV file."""
    merged_df.to_csv(save_path, index=False)

# %%
merged_df = find_nearest_drainage_density(df_wells=df, df_drainage_density=df_drainage_density)
save_data(merged_df=merged_df, save_path='../../data/final_dataset/processed_data/jay_merged_data.csv')
# Out:
# Analizando fila 1/2874
# Coincidencia más cercana encontrada en el índice 15213857: 13.499495506286621
# Datos combinados: {'long': -16.6706159583, 'lat': 13.48834562, 'Drainage_density': 13.499495506286621}
#
# Analizando fila 2/2874
# Coincidencia más cercana encontrada en el índice 15213874: 14.573663711547852
# Datos combinados: {'long': -16.6659979412, 'lat': 13.4883763217, 'Drainage_density': 14.573663711547852}
#
# Analizando fila 3/2874
# Coincidencia más cercana encontrada en el índice 15399736: 15.60971450805664
# Datos combinados: {'long': -16.6844382698, 'lat': 13.4837337841, 'Drainage_density': 15.60971450805664}
#
# Analizando fila 4/2874
# Coincidencia más cercana encontrada en el índice 15399753: 13.571120262145996
# Datos combinados: {'long': -16.6798203741, 'lat': 13.4837647298, 'Drainage_density': 13.571120262145996}
#
# Analizando fila 5/2874
# Coincidencia más cercana encontrada en el índice 15399770: 13.922872543334961
# Datos combinados: {'long': -16.6752024668, 'lat': 13.4837955906, 'Drainage_density': 13.922872543334961}
#
# Analizando fila 6/2874
# Coincidencia más cercana encontrada en el índice 15399786: 16.095518112182617
# Datos combinados: {'long': -16.670584548, 'lat': 13.4838263665, 'Drainage_density': 16.095518112182617}
#
# Analizando fila 7/2874
# Coincidencia más cercana encontrada en el índice 15399803: 18.692808151245117
# Datos combinados: {'long': -16.6659666176, 'lat': 13.4838570576, 'Drainage_density': 18.692808151245117}
#
# Analizando fila 8/2874
# Coincidencia más cercana encontrada en el índice 15585632: 25.523223876953125
# Datos combinados: {'long': -16.6936421931, 'lat': 13.4791524378, 'Drainage_density': 25.523223876953125}
#
# Analizando fila 9/2874
# Coincidencia más cercana encontrada en el índice 15574712: 26.205150604248047
# Datos combinados: {'long': -16.6890244074, 'lat': 13.4791835423, 'Drainage_density': 26.205150604248047}
#
# Analizando fila 10/2874
# Coincidencia más cercana encontrada en el índice 15574729: 26.15681266784668
# Datos combinados: {'long': -16.6844066109, 'lat': 13.4792145621, 'Drainage_density': 26.15681266784668}
#
# Analizando fila 11/2874
# Coincidencia más cercana encontrada en el índice 15574745: 23.96424674987793
# Datos combinados: {'long': -16.6797888019, 'lat': 13.479245497, 'Drainage_density': 23.96424674987793}
#
# Analizando fila 12/2874
# Coincidencia más cercana encontrada en el índice 15574762: 21.369871139526367
# Datos combinados: {'long': -16.6751709813, 'lat': 13.4792763471, 'Drainage_density': 21.369871139526367}
#
# Analizando fila 13/2874
# Coincidencia más cercana encontrada en el índice 15574778: 19.080493927001953
# Datos combinados: {'long': -16.6705531492, 'lat': 13.4793071123, 'Drainage_density': 19.080493927001953}
#
# Analizando fila 14/2874
# Coincidencia más cercana encontrada en el índice 15574795: 20.935293197631836
# Datos combinados: {'long': -16.6659353056, 'lat': 13.4793377928, 'Drainage_density': 20.935293197631836}
#
# Analizando fila 15/2874
# Coincidencia más cercana encontrada en el índice 15574812: 23.82297706604004
# Datos combinados: {'long': -16.6613174505, 'lat': 13.4793683884, 'Drainage_density': 23.82297706604004}
#
# Analizando fila 16/2874
# Coincidencia más cercana encontrada en el índice 15760608: 23.59632682800293
# Datos combinados: {'long': -16.69822806, 'lat': 13.4746020561, 'Drainage_density': 23.59632682800293}
#
# Analizando fila 17/2874
# Coincidencia más cercana encontrada en el índice 15760624: 28.036983489990234
# Datos combinados: {'long': -16.6936103726, 'lat': 13.4746332347, 'Drainage_density': 28.036983489990234}
#
# Analizando fila 18/2874
# Coincidencia más cercana encontrada en el índice 15760641: 30.25016975402832
# Datos combinados: {'long': -16.6889926735, 'lat': 13.4746643285, 'Drainage_density': 30.25016975402832}
#
# Analizando fila 19/2874
# Coincidencia más cercana encontrada en el índice 15760658: 31.12335777282715
# Datos combinados: {'long': -16.6843749637, 'lat': 13.4746953374, 'Drainage_density': 31.12335777282715}
#
# Analizando fila 20/2874
# Coincidencia más cercana encontrada en el índice 15749737: 31.512859344482422
# Datos combinados: {'long': -16.6797572413, 'lat': 13.4747262616, 'Drainage_density': 31.512859344482422}
#
# Analizando fila 21/2874
# Coincidencia más cercana encontrada en el índice 15749754: 30.241748809814453
# Datos combinados: {'long': -16.6751395074, 'lat': 13.474757101, 'Drainage_density': 30.241748809814453}
#
# Analizando fila 22/2874
# Coincidencia más cercana encontrada en el índice 15749771: 28.07442283630371
# Datos combinados: {'long': -16.6705217619, 'lat': 13.4747878555, 'Drainage_density': 28.07442283630371}
#
# Analizando fila 23/2874
# Coincidencia más cercana encontrada en el índice 15749787: 28.43528938293457
# Datos combinados: {'long': -16.665904005, 'lat': 13.4748185253, 'Drainage_density': 28.43528938293457}
#
# Analizando fila 24/2874
# Coincidencia más cercana encontrada en el índice 15749804: 31.545629501342773
# Datos combinados: {'long': -16.6612862365, 'lat': 13.4748491103, 'Drainage_density': 31.545629501342773}
#
# Analizando fila 25/2874
# Coincidencia más cercana encontrada en el índice 15749820: 31.37018394470215
# Datos combinados: {'long': -16.6566684576, 'lat': 13.4748796104, 'Drainage_density': 31.37018394470215}
#
# Analizando fila 26/2874
# Coincidencia más cercana encontrada en el índice 15749837: 31.14781379699707
# Datos combinados: {'long': -16.6520506663, 'lat': 13.4749100257, 'Drainage_density': 31.14781379699707}
#
# Analizando fila 27/2874
# Coincidencia más cercana encontrada en el índice 15749854: 28.993804931640625
# Datos combinados: {'long': -16.6474328636, 'lat': 13.4749403563, 'Drainage_density': 28.993804931640625}
#
# Analizando fila 28/2874
# Coincidencia más cercana encontrada en el índice 15749870: 24.337461471557617
# Datos combinados: {'long': -16.6428150496, 'lat': 13.474970602, 'Drainage_density': 24.337461471557617}
#
# Analizando fila 29/2874
# Coincidencia más cercana encontrada en el índice 15738950: 20.164520263671875
# Datos combinados: {'long': -16.6381972242, 'lat': 13.4750007629, 'Drainage_density': 20.164520263671875}
#
# Analizando fila 30/2874
# Coincidencia más cercana encontrada en el índice 15739016: 15.11854076385498
# Datos combinados: {'long': -16.6197258112, 'lat': 13.4751205585, 'Drainage_density': 15.11854076385498}
#
# Analizando fila 31/2874
# Coincidencia más cercana encontrada en el índice 15739033: 15.699274063110352
# Datos combinados: {'long': -16.6151079297, 'lat': 13.4751502953, 'Drainage_density': 15.699274063110352}
#
# Analizando fila 32/2874
# Coincidencia más cercana encontrada en el índice 15739050: 14.211244583129883
# Datos combinados: {'long': -16.6104900371, 'lat': 13.4751799474, 'Drainage_density': 14.211244583129883}
#
# Analizando fila 33/2874
# Coincidencia más cercana encontrada en el índice 15935583: 22.847599029541016
# Datos combinados: {'long': -16.7028137536, 'lat': 13.4700516097, 'Drainage_density': 22.847599029541016}
#
# Analizando fila 34/2874
# Coincidencia más cercana encontrada en el índice 15935600: 26.766586303710938
# Datos combinados: {'long': -16.6981961645, 'lat': 13.4700828622, 'Drainage_density': 26.766586303710938}
#
# Analizando fila 35/2874
# Coincidencia más cercana encontrada en el índice 15935617: 30.41116714477539
# Datos combinados: {'long': -16.6935785637, 'lat': 13.47011403, 'Drainage_density': 30.41116714477539}
#
# Analizando fila 36/2874
# Coincidencia más cercana encontrada en el índice 15935633: 32.436458587646484
# Datos combinados: {'long': -16.6889609512, 'lat': 13.4701451129, 'Drainage_density': 32.436458587646484}
#
# Analizando fila 37/2874
# Coincidencia más cercana encontrada en el índice 15935650: 37.64985275268555
# Datos combinados: {'long': -16.684343328, 'lat': 13.4701761111, 'Drainage_density': 37.64985275268555}
#
# Analizando fila 38/2874
# Coincidencia más cercana encontrada en el índice 15935666: 38.23439407348633
# Datos combinados: {'long': -16.6797256923, 'lat': 13.4702070245, 'Drainage_density': 38.23439407348633}
#
# Analizando fila 39/2874
# Coincidencia más cercana encontrada en el índice 15935683: 42.82203674316406
# Datos combinados: {'long': -16.675108045, 'lat': 13.4702378532, 'Drainage_density': 42.82203674316406}
#
# Analizando fila 40/2874
# Coincidencia más cercana encontrada en el índice 15935700: 45.694847106933594
# Datos combinados: {'long': -16.6704903862, 'lat': 13.470268597, 'Drainage_density': 45.694847106933594}
#
# Analizando fila 41/2874
# Coincidencia más cercana encontrada en el índice 15924779: 42.35110855102539
# Datos combinados: {'long': -16.6658727159, 'lat': 13.4702992561, 'Drainage_density': 42.35110855102539}
#
# Analizando fila 42/2874
# Coincidencia más cercana encontrada en el índice 15924796: 42.730499267578125
# Datos combinados: {'long': -16.661255034, 'lat': 13.4703298305, 'Drainage_density': 42.730499267578125}
#
# Analizando fila 43/2874
# Coincidencia más cercana encontrada en el índice 15924813: 42.554080963134766
# Datos combinados: {'long': -16.6566373417, 'lat': 13.47036032, 'Drainage_density': 42.554080963134766}
#
# Analizando fila 44/2874
# Coincidencia más cercana encontrada en el índice 15924829: 38.35965347290039
# Datos combinados: {'long': -16.6520196371, 'lat': 13.4703907248, 'Drainage_density': 38.35965347290039}
#
# Analizando fila 45/2874
# Coincidencia más cercana encontrada en el índice 15924846: 36.61771774291992
# Datos combinados: {'long': -16.647401921, 'lat': 13.4704210448, 'Drainage_density': 36.61771774291992}
#
# Analizando fila 46/2874
# Coincidencia más cercana encontrada en el índice 15924862: 31.270469665527344
# Datos combinados: {'long': -16.6427841936, 'lat': 13.47045128, 'Drainage_density': 31.270469665527344}
#
# Analizando fila 47/2874
# Coincidencia más cercana encontrada en el índice 15924879: 24.271514892578125
# Datos combinados: {'long': -16.6381664549, 'lat': 13.4704814304, 'Drainage_density': 24.271514892578125}
#
# Analizando fila 48/2874
# Coincidencia más cercana encontrada en el índice 15924896: 20.189620971679688
# Datos combinados: {'long': -16.6335487049, 'lat': 13.4705114961, 'Drainage_density': 20.189620971679688}
#
# Analizando fila 49/2874
# Coincidencia más cercana encontrada en el índice 15924912: 16.891489028930664
# Datos combinados: {'long': -16.6289309437, 'lat': 13.4705414769, 'Drainage_density': 16.891489028930664}
#
# Analizando fila 50/2874
# Coincidencia más cercana encontrada en el índice 15913992: 16.435279846191406
# Datos combinados: {'long': -16.6243131721, 'lat': 13.470571373, 'Drainage_density': 16.435279846191406}
#
# Analizando fila 51/2874
# Coincidencia más cercana encontrada en el índice 15914009: 19.110671997070312
# Datos combinados: {'long': -16.6196953884, 'lat': 13.4706011843, 'Drainage_density': 19.110671997070312}
#
# Analizando fila 52/2874
# Coincidencia más cercana encontrada en el índice 15914025: 21.830909729003906
# Datos combinados: {'long': -16.6150775936, 'lat': 13.4706309108, 'Drainage_density': 21.830909729003906}
#
# Analizando fila 53/2874
# Coincidencia más cercana encontrada en el índice 15914042: 20.52651023864746
# Datos combinados: {'long': -16.6104597877, 'lat': 13.4706605526, 'Drainage_density': 20.52651023864746}
#
# Analizando fila 54/2874
# Coincidencia más cercana encontrada en el índice 15914058: 18.308744430541992
# Datos combinados: {'long': -16.6058419706, 'lat': 13.4706901095, 'Drainage_density': 18.308744430541992}
#
# Analizando fila 55/2874
# Coincidencia más cercana encontrada en el índice 15914075: 18.274532318115234
# Datos combinados: {'long': -16.6012241425, 'lat': 13.4707195817, 'Drainage_density': 18.274532318115234}
#
# Analizando fila 56/2874
# Coincidencia más cercana encontrada en el índice 16121496: 23.404098510742188
# Datos combinados: {'long': -16.7073992739, 'lat': 13.4655010986, 'Drainage_density': 23.404098510742188}
#
# Analizando fila 57/2874
# Coincidencia más cercana encontrada en el índice 16121512: 26.03175926208496
# Datos combinados: {'long': -16.7027817832, 'lat': 13.465532425, 'Drainage_density': 26.03175926208496}
#
# Analizando fila 58/2874
# Coincidencia más cercana encontrada en el índice 16110592: 29.048416137695312
# Datos combinados: {'long': -16.6981642806, 'lat': 13.4655636666, 'Drainage_density': 29.048416137695312}
#
# Analizando fila 59/2874
# Coincidencia más cercana encontrada en el índice 16110609: 32.054710388183594
# Datos combinados: {'long': -16.6935467664, 'lat': 13.4655948235, 'Drainage_density': 32.054710388183594}
#
# Analizando fila 60/2874
# Coincidencia más cercana encontrada en el índice 16110625: 35.36440658569336
# Datos combinados: {'long': -16.6889292406, 'lat': 13.4656258957, 'Drainage_density': 35.36440658569336}
#
# Analizando fila 61/2874
# Coincidencia más cercana encontrada en el índice 16110642: 42.788848876953125
# Datos combinados: {'long': -16.684311704, 'lat': 13.4656568831, 'Drainage_density': 42.788848876953125}
#
# Analizando fila 62/2874
# Coincidencia más cercana encontrada en el índice 16110659: 50.46803665161133
# Datos combinados: {'long': -16.6796941548, 'lat': 13.4656877857, 'Drainage_density': 50.46803665161133}
#
# Analizando fila 63/2874
# Coincidencia más cercana encontrada en el índice 16110675: 61.476436614990234
# Datos combinados: {'long': -16.6750765942, 'lat': 13.4657186037, 'Drainage_density': 61.476436614990234}
#
# Analizando fila 64/2874
# Coincidencia más cercana encontrada en el índice 16110692: 58.55062484741211
# Datos combinados: {'long': -16.6704590219, 'lat': 13.4657493369, 'Drainage_density': 58.55062484741211}
#
# Analizando fila 65/2874
# Coincidencia más cercana encontrada en el índice 16110708: 54.61455535888672
# Datos combinados: {'long': -16.6658414382, 'lat': 13.4657799853, 'Drainage_density': 54.61455535888672}
#
# Analizando fila 66/2874
# Coincidencia más cercana encontrada en el índice 16110725: 51.00869369506836
# Datos combinados: {'long': -16.661223843, 'lat': 13.465810549, 'Drainage_density': 51.00869369506836}
#
# Analizando fila 67/2874
# Coincidencia más cercana encontrada en el índice 16099805: 46.91873550415039
# Datos combinados: {'long': -16.6566062373, 'lat': 13.4658410279, 'Drainage_density': 46.91873550415039}
#
# Analizando fila 68/2874
# Coincidencia más cercana encontrada en el índice 16099821: 48.45954513549805
# Datos combinados: {'long': -16.6519886192, 'lat': 13.4658714221, 'Drainage_density': 48.45954513549805}
#
# Analizando fila 69/2874
# Coincidencia más cercana encontrada en el índice 16099838: 40.720638275146484
# Datos combinados: {'long': -16.6473709898, 'lat': 13.4659017316, 'Drainage_density': 40.720638275146484}
#
# Analizando fila 70/2874
# Coincidencia más cercana encontrada en el índice 16099855: 33.810218811035156
# Datos combinados: {'long': -16.642753349, 'lat': 13.4659319563, 'Drainage_density': 33.810218811035156}
#
# Analizando fila 71/2874
# Coincidencia más cercana encontrada en el índice 16099871: 29.553152084350586
# Datos combinados: {'long': -16.6381356969, 'lat': 13.4659620962, 'Drainage_density': 29.553152084350586}
#
# Analizando fila 72/2874
# Coincidencia más cercana encontrada en el índice 16099888: 25.182758331298828
# Datos combinados: {'long': -16.6335180335, 'lat': 13.4659921514, 'Drainage_density': 25.182758331298828}
#
# Analizando fila 73/2874
# Coincidencia más cercana encontrada en el índice 16099904: 22.76255226135254
# Datos combinados: {'long': -16.6289003589, 'lat': 13.4660221219, 'Drainage_density': 22.76255226135254}
#
# Analizando fila 74/2874
# Coincidencia más cercana encontrada en el índice 16099921: 20.716827392578125
# Datos combinados: {'long': -16.6242826739, 'lat': 13.4660520076, 'Drainage_density': 20.716827392578125}
#
# Analizando fila 75/2874
# Coincidencia más cercana encontrada en el índice 16099938: 21.0312557220459
# Datos combinados: {'long': -16.6196649769, 'lat': 13.4660818085, 'Drainage_density': 21.0312557220459}
#
# Analizando fila 76/2874
# Coincidencia más cercana encontrada en el índice 16089017: 21.654096603393555
# Datos combinados: {'long': -16.6150472687, 'lat': 13.4661115247, 'Drainage_density': 21.654096603393555}
#
# Analizando fila 77/2874
# Coincidencia más cercana encontrada en el índice 16089034: 20.19330596923828
# Datos combinados: {'long': -16.6104295493, 'lat': 13.4661411561, 'Drainage_density': 20.19330596923828}
#
# Analizando fila 78/2874
# Coincidencia más cercana encontrada en el índice 16089050: 21.195960998535156
# Datos combinados: {'long': -16.6058118189, 'lat': 13.4661707028, 'Drainage_density': 21.195960998535156}
#
# Analizando fila 79/2874
# Coincidencia más cercana encontrada en el índice 16089067: 20.869876861572266
# Datos combinados: {'long': -16.6011940774, 'lat': 13.4662001647, 'Drainage_density': 20.869876861572266}
#
# Analizando fila 80/2874
# Coincidencia más cercana encontrada en el índice 16089084: 22.075414657592773
# Datos combinados: {'long': -16.5965763249, 'lat': 13.4662295418, 'Drainage_density': 22.075414657592773}
#
# Analizando fila 81/2874
# Coincidencia más cercana encontrada en el índice 16296471: 26.647069931030273
# Datos combinados: {'long': -16.7119846212, 'lat': 13.4609505229, 'Drainage_density': 26.647069931030273}
#
# Analizando fila 82/2874
# Coincidencia más cercana encontrada en el índice 16296488: 31.987150192260742
# Datos combinados: {'long': -16.7073672287, 'lat': 13.4609819231, 'Drainage_density': 31.987150192260742}
#
# Analizando fila 83/2874
# Coincidencia más cercana encontrada en el índice 16296505: 34.62004470825195
# Datos combinados: {'long': -16.7027498245, 'lat': 13.4610132385, 'Drainage_density': 34.62004470825195}
#
# Analizando fila 84/2874
# Coincidencia más cercana encontrada en el índice 16296521: 39.23304748535156
# Datos combinados: {'long': -16.6981324085, 'lat': 13.4610444693, 'Drainage_density': 39.23304748535156}
#
# Analizando fila 85/2874
# Coincidencia más cercana encontrada en el índice 16296538: 43.25423049926758
# Datos combinados: {'long': -16.6935149809, 'lat': 13.4610756154, 'Drainage_density': 43.25423049926758}
#
# Analizando fila 86/2874
# Coincidencia más cercana encontrada en el índice 16296554: 47.44767379760742
# Datos combinados: {'long': -16.6888975415, 'lat': 13.4611066767, 'Drainage_density': 47.44767379760742}
#
# Analizando fila 87/2874
# Coincidencia más cercana encontrada en el índice 16285634: 51.790950775146484
# Datos combinados: {'long': -16.6842800915, 'lat': 13.4611376533, 'Drainage_density': 51.790950775146484}
#
# Analizando fila 88/2874
# Coincidencia más cercana encontrada en el índice 16285651: 64.65544128417969
# Datos combinados: {'long': -16.679662629, 'lat': 13.4611685453, 'Drainage_density': 64.65544128417969}
#
# Analizando fila 89/2874
# Coincidencia más cercana encontrada en el índice 16285667: 70.51282501220703
# Datos combinados: {'long': -16.6750451549, 'lat': 13.4611993525, 'Drainage_density': 70.51282501220703}
#
# Analizando fila 90/2874
# Coincidencia más cercana encontrada en el índice 16285684: 62.73940658569336
# Datos combinados: {'long': -16.6704276692, 'lat': 13.461230075, 'Drainage_density': 62.73940658569336}
#
# Analizando fila 91/2874
# Coincidencia más cercana encontrada en el índice 16285700: 58.47124481201172
# Datos combinados: {'long': -16.665810172, 'lat': 13.4612607128, 'Drainage_density': 58.47124481201172}
#
# Analizando fila 92/2874
# Coincidencia más cercana encontrada en el índice 16285717: 53.277374267578125
# Datos combinados: {'long': -16.6611926634, 'lat': 13.4612912658, 'Drainage_density': 53.277374267578125}
#
# Analizando fila 93/2874
# Coincidencia más cercana encontrada en el índice 16285734: 53.60859298706055
# Datos combinados: {'long': -16.6565751442, 'lat': 13.4613217342, 'Drainage_density': 53.60859298706055}
#
# Analizando fila 94/2874
# Coincidencia más cercana encontrada en el índice 16285750: 54.372093200683594
# Datos combinados: {'long': -16.6519576128, 'lat': 13.4613521178, 'Drainage_density': 54.372093200683594}
#
# Analizando fila 95/2874
# Coincidencia más cercana encontrada en el índice 16285767: 47.68256759643555
# Datos combinados: {'long': -16.6473400699, 'lat': 13.4613824167, 'Drainage_density': 47.68256759643555}
#
# Analizando fila 96/2874
# Coincidencia más cercana encontrada en el índice 16274847: 36.85717010498047
# Datos combinados: {'long': -16.6427225157, 'lat': 13.4614126309, 'Drainage_density': 36.85717010498047}
#
# Analizando fila 97/2874
# Coincidencia más cercana encontrada en el índice 16274863: 32.13805389404297
# Datos combinados: {'long': -16.6381049501, 'lat': 13.4614427603, 'Drainage_density': 32.13805389404297}
#
# Analizando fila 98/2874
# Coincidencia más cercana encontrada en el índice 16274880: 32.006919860839844
# Datos combinados: {'long': -16.6334873733, 'lat': 13.4614728051, 'Drainage_density': 32.006919860839844}
#
# Analizando fila 99/2874
# Coincidencia más cercana encontrada en el índice 16274896: 26.669574737548828
# Datos combinados: {'long': -16.6288697853, 'lat': 13.4615027651, 'Drainage_density': 26.669574737548828}
#
# Analizando fila 100/2874
# Coincidencia más cercana encontrada en el índice 16274913: 22.483943939208984
# Datos combinados: {'long': -16.6242521869, 'lat': 13.4615326404, 'Drainage_density': 22.483943939208984}
#
# Analizando fila 101/2874
# Coincidencia más cercana encontrada en el índice 16274930: 23.22875213623047
# Datos combinados: {'long': -16.6196345764, 'lat': 13.461562431, 'Drainage_density': 23.22875213623047}
#
# Analizando fila 102/2874
# Coincidencia más cercana encontrada en el índice 16274946: 23.820438385009766
# Datos combinados: {'long': -16.6150169548, 'lat': 13.4615921368, 'Drainage_density': 23.820438385009766}
#
# Analizando fila 103/2874
# Coincidencia más cercana encontrada en el índice 16274963: 23.058080673217773
# Datos combinados: {'long': -16.6103993221, 'lat': 13.4616217579, 'Drainage_density': 23.058080673217773}
#
# Analizando fila 104/2874
# Coincidencia más cercana encontrada en el índice 16274980: 23.381244659423828
# Datos combinados: {'long': -16.6057816782, 'lat': 13.4616512943, 'Drainage_density': 23.381244659423828}
#
# Analizando fila 105/2874
# Coincidencia más cercana encontrada en el índice 16264059: 21.512243270874023
# Datos combinados: {'long': -16.6011640233, 'lat': 13.461680746, 'Drainage_density': 21.512243270874023}
#
# Analizando fila 106/2874
# Coincidencia más cercana encontrada en el índice 16264076: 22.09242820739746
# Datos combinados: {'long': -16.5965463574, 'lat': 13.4617101129, 'Drainage_density': 22.09242820739746}
#
# Analizando fila 107/2874
# Coincidencia más cercana encontrada en el índice 16264092: 21.862104415893555
# Datos combinados: {'long': -16.5919286814, 'lat': 13.4617393951, 'Drainage_density': 21.862104415893555}
#
# Analizando fila 108/2874
# Coincidencia más cercana encontrada en el índice 16264109: 20.03533363342285
# Datos combinados: {'long': -16.5873109935, 'lat': 13.4617685926, 'Drainage_density': 20.03533363342285}
#
# Analizando fila 109/2874
# Coincidencia más cercana encontrada en el índice 16264126: 9.80571174621582
# Datos combinados: {'long': -16.5826932946, 'lat': 13.4617977053, 'Drainage_density': 9.80571174621582}
#
# Analizando fila 110/2874
# Coincidencia más cercana encontrada en el índice 16264142: 7.369265079498291
# Datos combinados: {'long': -16.5780755849, 'lat': 13.4618267333, 'Drainage_density': 7.369265079498291}
#
# Analizando fila 111/2874
# Coincidencia más cercana encontrada en el índice 16471447: 26.557153701782227
# Datos combinados: {'long': -16.7165697953, 'lat': 13.4563998826, 'Drainage_density': 26.557153701782227}
#
# Analizando fila 112/2874
# Coincidencia más cercana encontrada en el índice 16471463: 37.47385025024414
# Datos combinados: {'long': -16.7119525011, 'lat': 13.4564313566, 'Drainage_density': 37.47385025024414}
#
# Analizando fila 113/2874
# Coincidencia más cercana encontrada en el índice 16471480: 44.1298942565918
# Datos combinados: {'long': -16.7073351952, 'lat': 13.4564627458, 'Drainage_density': 44.1298942565918}
#
# Analizando fila 114/2874
# Coincidencia más cercana encontrada en el índice 16471497: 42.98526382446289
# Datos combinados: {'long': -16.7027178775, 'lat': 13.4564940504, 'Drainage_density': 42.98526382446289}
#
# Analizando fila 115/2874
# Coincidencia más cercana encontrada en el índice 16471513: 42.644309997558594
# Datos combinados: {'long': -16.6981005481, 'lat': 13.4565252703, 'Drainage_density': 42.644309997558594}
#
# Analizando fila 116/2874
# Coincidencia más cercana encontrada en el índice 16471530: 48.439937591552734
# Datos combinados: {'long': -16.693483207, 'lat': 13.4565564055, 'Drainage_density': 48.439937591552734}
#
# Analizando fila 117/2874
# Coincidencia más cercana encontrada en el índice 16471546: 54.14271545410156
# Datos combinados: {'long': -16.6888658542, 'lat': 13.4565874561, 'Drainage_density': 54.14271545410156}
#
# Analizando fila 118/2874
# Coincidencia más cercana encontrada en el índice 16471563: 59.601444244384766
# Datos combinados: {'long': -16.6842484907, 'lat': 13.4566184219, 'Drainage_density': 59.601444244384766}
#
# Analizando fila 119/2874
# Coincidencia más cercana encontrada en el índice 16471580: 80.45915222167969
# Datos combinados: {'long': -16.6796311147, 'lat': 13.4566493031, 'Drainage_density': 80.45915222167969}
#
# Analizando fila 120/2874
# Coincidencia más cercana encontrada en el índice 16460659: 79.59593963623047
# Datos combinados: {'long': -16.6750137271, 'lat': 13.4566800996, 'Drainage_density': 79.59593963623047}
#
# Analizando fila 121/2874
# Coincidencia más cercana encontrada en el índice 16460676: 75.58573150634766
# Datos combinados: {'long': -16.670396328, 'lat': 13.4567108114, 'Drainage_density': 75.58573150634766}
#
# Analizando fila 122/2874
# Coincidencia más cercana encontrada en el índice 16460693: 68.28052520751953
# Datos combinados: {'long': -16.6657789173, 'lat': 13.4567414385, 'Drainage_density': 68.28052520751953}
#
# Analizando fila 123/2874
# Coincidencia más cercana encontrada en el índice 16460709: 62.45866775512695
# Datos combinados: {'long': -16.6611614952, 'lat': 13.456771981, 'Drainage_density': 62.45866775512695}
#
# Analizando fila 124/2874
# Coincidencia más cercana encontrada en el índice 16460726: 58.14810562133789
# Datos combinados: {'long': -16.6565440626, 'lat': 13.4568024387, 'Drainage_density': 58.14810562133789}
#
# Analizando fila 125/2874
# Coincidencia más cercana encontrada en el índice 16460742: 59.878116607666016
# Datos combinados: {'long': -16.6519266177, 'lat': 13.4568328117, 'Drainage_density': 59.878116607666016}
#
# Analizando fila 126/2874
# Coincidencia más cercana encontrada en el índice 16460759: 48.452293395996094
# Datos combinados: {'long': -16.6473091614, 'lat': 13.4568631001, 'Drainage_density': 48.452293395996094}
#
# Analizando fila 127/2874
# Coincidencia más cercana encontrada en el índice 16460776: 41.6748046875
# Datos combinados: {'long': -16.6426916937, 'lat': 13.4568933038, 'Drainage_density': 41.6748046875}
#
# Analizando fila 128/2874
# Coincidencia más cercana encontrada en el índice 16460792: 35.76996994018555
# Datos combinados: {'long': -16.6380742147, 'lat': 13.4569234228, 'Drainage_density': 35.76996994018555}
#
# Analizando fila 129/2874
# Coincidencia más cercana encontrada en el índice 16449872: 38.07823944091797
# Datos combinados: {'long': -16.6334567244, 'lat': 13.4569534571, 'Drainage_density': 38.07823944091797}
#
# Analizando fila 130/2874
# Coincidencia más cercana encontrada en el índice 16449889: 32.12002944946289
# Datos combinados: {'long': -16.6288392229, 'lat': 13.4569834067, 'Drainage_density': 32.12002944946289}
#
# Analizando fila 131/2874
# Coincidencia más cercana encontrada en el índice 16449905: 26.70503044128418
# Datos combinados: {'long': -16.6242217111, 'lat': 13.4570132716, 'Drainage_density': 26.70503044128418}
#
# Analizando fila 132/2874
# Coincidencia más cercana encontrada en el índice 16449922: 25.80215072631836
# Datos combinados: {'long': -16.6196041872, 'lat': 13.4570430518, 'Drainage_density': 25.80215072631836}
#
# Analizando fila 133/2874
# Coincidencia más cercana encontrada en el índice 16449938: 25.673370361328125
# Datos combinados: {'long': -16.6149866521, 'lat': 13.4570727473, 'Drainage_density': 25.673370361328125}
#
# Analizando fila 134/2874
# Coincidencia más cercana encontrada en el índice 16449955: 26.829605102539062
# Datos combinados: {'long': -16.6103691059, 'lat': 13.4571023581, 'Drainage_density': 26.829605102539062}
#
# Analizando fila 135/2874
# Coincidencia más cercana encontrada en el índice 16449972: 26.163846969604492
# Datos combinados: {'long': -16.6057515486, 'lat': 13.4571318842, 'Drainage_density': 26.163846969604492}
#
# Analizando fila 136/2874
# Coincidencia más cercana encontrada en el índice 16449988: 24.156028747558594
# Datos combinados: {'long': -16.6011339802, 'lat': 13.4571613256, 'Drainage_density': 24.156028747558594}
#
# Analizando fila 137/2874
# Coincidencia más cercana encontrada en el índice 16450005: 22.09242820739746
# Datos combinados: {'long': -16.5965164009, 'lat': 13.4571906823, 'Drainage_density': 22.09242820739746}
#
# Analizando fila 138/2874
# Coincidencia más cercana encontrada en el índice 16450022: 22.09242820739746
# Datos combinados: {'long': -16.5918988114, 'lat': 13.4572199543, 'Drainage_density': 22.09242820739746}
#
# Analizando fila 139/2874
# Coincidencia más cercana encontrada en el índice 16439101: 20.678783416748047
# Datos combinados: {'long': -16.5872812101, 'lat': 13.4572491416, 'Drainage_density': 20.678783416748047}
#
# Analizando fila 140/2874
# Coincidencia más cercana encontrada en el índice 16439118: 9.267789840698242
# Datos combinados: {'long': -16.5826635978, 'lat': 13.4572782442, 'Drainage_density': 9.267789840698242}
#
# Analizando fila 141/2874
# Coincidencia más cercana encontrada en el índice 16439134: 6.485226154327393
# Datos combinados: {'long': -16.5780459746, 'lat': 13.4573072621, 'Drainage_density': 6.485226154327393}
#
# Analizando fila 142/2874
# Coincidencia más cercana encontrada en el índice 16439151: 6.131608963012695
# Datos combinados: {'long': -16.5734283405, 'lat': 13.4573361953, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 143/2874
# Coincidencia más cercana encontrada en el índice 16439168: 6.131608963012695
# Datos combinados: {'long': -16.5688106957, 'lat': 13.4573650438, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 144/2874
# Coincidencia más cercana encontrada en el índice 16657359: 21.318099975585938
# Datos combinados: {'long': -16.7211547955, 'lat': 13.4518491779, 'Drainage_density': 21.318099975585938}
#
# Analizando fila 145/2874
# Coincidencia más cercana encontrada en el índice 16657376: 29.624338150024414
# Datos combinados: {'long': -16.7165376005, 'lat': 13.4518807256, 'Drainage_density': 29.624338150024414}
#
# Analizando fila 146/2874
# Coincidencia más cercana encontrada en el índice 16657393: 45.601749420166016
# Datos combinados: {'long': -16.7119203929, 'lat': 13.4519121886, 'Drainage_density': 45.601749420166016}
#
# Analizando fila 147/2874
# Coincidencia más cercana encontrada en el índice 16657409: 52.9269905090332
# Datos combinados: {'long': -16.7073031735, 'lat': 13.4519435669, 'Drainage_density': 52.9269905090332}
#
# Analizando fila 148/2874
# Coincidencia más cercana encontrada en el índice 16646489: 53.235042572021484
# Datos combinados: {'long': -16.7026859423, 'lat': 13.4519748606, 'Drainage_density': 53.235042572021484}
#
# Analizando fila 149/2874
# Coincidencia más cercana encontrada en el índice 16646505: 51.11900329589844
# Datos combinados: {'long': -16.6980686993, 'lat': 13.4520060696, 'Drainage_density': 51.11900329589844}
#
# Analizando fila 150/2874
# Coincidencia más cercana encontrada en el índice 16646522: 55.35823059082031
# Datos combinados: {'long': -16.6934514447, 'lat': 13.452037194, 'Drainage_density': 55.35823059082031}
#
# Analizando fila 151/2874
# Coincidencia más cercana encontrada en el índice 16646539: 64.85186004638672
# Datos combinados: {'long': -16.6888341784, 'lat': 13.4520682337, 'Drainage_density': 64.85186004638672}
#
# Analizando fila 152/2874
# Coincidencia más cercana encontrada en el índice 16646555: 69.59889221191406
# Datos combinados: {'long': -16.6842169014, 'lat': 13.4520991888, 'Drainage_density': 69.59889221191406}
#
# Analizando fila 153/2874
# Coincidencia más cercana encontrada en el índice 16646572: 83.43073272705078
# Datos combinados: {'long': -16.6795996119, 'lat': 13.4521300592, 'Drainage_density': 83.43073272705078}
#
# Analizando fila 154/2874
# Coincidencia más cercana encontrada en el índice 16646588: 89.68053436279297
# Datos combinados: {'long': -16.6749823108, 'lat': 13.452160845, 'Drainage_density': 89.68053436279297}
#
# Analizando fila 155/2874
# Coincidencia más cercana encontrada en el índice 16646605: 77.20970153808594
# Datos combinados: {'long': -16.6703649982, 'lat': 13.4521915461, 'Drainage_density': 77.20970153808594}
#
# Analizando fila 156/2874
# Coincidencia más cercana encontrada en el índice 16646622: 70.26847076416016
# Datos combinados: {'long': -16.6657476741, 'lat': 13.4522221626, 'Drainage_density': 70.26847076416016}
#
# Analizando fila 157/2874
# Coincidencia más cercana encontrada en el índice 16635701: 63.0425910949707
# Datos combinados: {'long': -16.6611303385, 'lat': 13.4522526944, 'Drainage_density': 63.0425910949707}
#
# Analizando fila 158/2874
# Coincidencia más cercana encontrada en el índice 16635718: 58.330047607421875
# Datos combinados: {'long': -16.6565129924, 'lat': 13.4522831415, 'Drainage_density': 58.330047607421875}
#
# Analizando fila 159/2874
# Coincidencia más cercana encontrada en el índice 16635735: 56.85635757446289
# Datos combinados: {'long': -16.651895634, 'lat': 13.452313504, 'Drainage_density': 56.85635757446289}
#
# Analizando fila 160/2874
# Coincidencia más cercana encontrada en el índice 16635751: 51.88917541503906
# Datos combinados: {'long': -16.6472782642, 'lat': 13.4523437818, 'Drainage_density': 51.88917541503906}
#
# Analizando fila 161/2874
# Coincidencia más cercana encontrada en el índice 16635768: 45.88709259033203
# Datos combinados: {'long': -16.642660883, 'lat': 13.452373975, 'Drainage_density': 45.88709259033203}
#
# Analizando fila 162/2874
# Coincidencia más cercana encontrada en el índice 16635784: 40.92817687988281
# Datos combinados: {'long': -16.6380434905, 'lat': 13.4524040835, 'Drainage_density': 40.92817687988281}
#
# Analizando fila 163/2874
# Coincidencia más cercana encontrada en el índice 16635801: 44.85731506347656
# Datos combinados: {'long': -16.6334260868, 'lat': 13.4524341073, 'Drainage_density': 44.85731506347656}
#
# Analizando fila 164/2874
# Coincidencia más cercana encontrada en el índice 16635818: 35.849143981933594
# Datos combinados: {'long': -16.6288086718, 'lat': 13.4524640465, 'Drainage_density': 35.849143981933594}
#
# Analizando fila 165/2874
# Coincidencia más cercana encontrada en el índice 16635834: 27.205867767333984
# Datos combinados: {'long': -16.6241912465, 'lat': 13.452493901, 'Drainage_density': 27.205867767333984}
#
# Analizando fila 166/2874
# Coincidencia más cercana encontrada en el índice 16624914: 27.06928825378418
# Datos combinados: {'long': -16.6195738091, 'lat': 13.4525236709, 'Drainage_density': 27.06928825378418}
#
# Analizando fila 167/2874
# Coincidencia más cercana encontrada en el índice 16624931: 24.643163681030273
# Datos combinados: {'long': -16.6149563605, 'lat': 13.452553356, 'Drainage_density': 24.643163681030273}
#
# Analizando fila 168/2874
# Coincidencia más cercana encontrada en el índice 16624947: 27.184843063354492
# Datos combinados: {'long': -16.6103389008, 'lat': 13.4525829565, 'Drainage_density': 27.184843063354492}
#
# Analizando fila 169/2874
# Coincidencia más cercana encontrada en el índice 16624964: 27.184843063354492
# Datos combinados: {'long': -16.60572143, 'lat': 13.4526124724, 'Drainage_density': 27.184843063354492}
#
# Analizando fila 170/2874
# Coincidencia más cercana encontrada en el índice 16624980: 26.25333595275879
# Datos combinados: {'long': -16.6011039482, 'lat': 13.4526419035, 'Drainage_density': 26.25333595275879}
#
# Analizando fila 171/2874
# Coincidencia más cercana encontrada en el índice 16624997: 24.72972869873047
# Datos combinados: {'long': -16.5964864553, 'lat': 13.45267125, 'Drainage_density': 24.72972869873047}
#
# Analizando fila 172/2874
# Coincidencia más cercana encontrada en el índice 16625014: 22.09242820739746
# Datos combinados: {'long': -16.5918689524, 'lat': 13.4527005119, 'Drainage_density': 22.09242820739746}
#
# Analizando fila 173/2874
# Coincidencia más cercana encontrada en el índice 16625030: 20.45547866821289
# Datos combinados: {'long': -16.5872514376, 'lat': 13.452729689, 'Drainage_density': 20.45547866821289}
#
# Analizando fila 174/2874
# Coincidencia más cercana encontrada en el índice 16625047: 9.558940887451172
# Datos combinados: {'long': -16.5826339118, 'lat': 13.4527587815, 'Drainage_density': 9.558940887451172}
#
# Analizando fila 175/2874
# Coincidencia más cercana encontrada en el índice 16614127: 6.131608963012695
# Datos combinados: {'long': -16.5780163752, 'lat': 13.4527877893, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 176/2874
# Coincidencia más cercana encontrada en el índice 16614143: 6.131608963012695
# Datos combinados: {'long': -16.5733988277, 'lat': 13.4528167124, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 177/2874
# Coincidencia más cercana encontrada en el índice 16614160: 6.131608963012695
# Datos combinados: {'long': -16.5687812693, 'lat': 13.4528455509, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 178/2874
# Coincidencia más cercana encontrada en el índice 16832351: 20.131864547729492
# Datos combinados: {'long': -16.7211225261, 'lat': 13.4473300311, 'Drainage_density': 20.131864547729492}
#
# Analizando fila 179/2874
# Coincidencia más cercana encontrada en el índice 16832368: 31.13323211669922
# Datos combinados: {'long': -16.7165054176, 'lat': 13.4473615677, 'Drainage_density': 31.13323211669922}
#
# Analizando fila 180/2874
# Coincidencia más cercana encontrada en el índice 16832385: 53.226783752441406
# Datos combinados: {'long': -16.7118882965, 'lat': 13.4473930198, 'Drainage_density': 53.226783752441406}
#
# Analizando fila 181/2874
# Coincidencia más cercana encontrada en el índice 16832401: 57.428829193115234
# Datos combinados: {'long': -16.7072711635, 'lat': 13.4474243872, 'Drainage_density': 57.428829193115234}
#
# Analizando fila 182/2874
# Coincidencia más cercana encontrada en el índice 16832418: 65.13794708251953
# Datos combinados: {'long': -16.7026540187, 'lat': 13.44745567, 'Drainage_density': 65.13794708251953}
#
# Analizando fila 183/2874
# Coincidencia más cercana encontrada en el índice 16832434: 62.064292907714844
# Datos combinados: {'long': -16.6980368623, 'lat': 13.4474868681, 'Drainage_density': 62.064292907714844}
#
# Analizando fila 184/2874
# Coincidencia más cercana encontrada en el índice 16821514: 62.88437271118164
# Datos combinados: {'long': -16.6934196941, 'lat': 13.4475179817, 'Drainage_density': 62.88437271118164}
#
# Analizando fila 185/2874
# Coincidencia más cercana encontrada en el índice 16821531: 70.69027709960938
# Datos combinados: {'long': -16.6888025143, 'lat': 13.4475490106, 'Drainage_density': 70.69027709960938}
#
# Analizando fila 186/2874
# Coincidencia más cercana encontrada en el índice 16821547: 75.496337890625
# Datos combinados: {'long': -16.6841853238, 'lat': 13.4475799549, 'Drainage_density': 75.496337890625}
#
# Analizando fila 187/2874
# Coincidencia más cercana encontrada en el índice 16821564: 86.47065734863281
# Datos combinados: {'long': -16.6795681208, 'lat': 13.4476108146, 'Drainage_density': 86.47065734863281}
#
# Analizando fila 188/2874
# Coincidencia más cercana encontrada en el índice 16821581: 87.07878112792969
# Datos combinados: {'long': -16.6749509062, 'lat': 13.4476415896, 'Drainage_density': 87.07878112792969}
#
# Analizando fila 189/2874
# Coincidencia más cercana encontrada en el índice 16821597: 79.2219009399414
# Datos combinados: {'long': -16.67033368, 'lat': 13.4476722801, 'Drainage_density': 79.2219009399414}
#
# Analizando fila 190/2874
# Coincidencia más cercana encontrada en el índice 16821614: 71.85986328125
# Datos combinados: {'long': -16.6657164424, 'lat': 13.4477028859, 'Drainage_density': 71.85986328125}
#
# Analizando fila 191/2874
# Coincidencia más cercana encontrada en el índice 16821630: 62.0661735534668
# Datos combinados: {'long': -16.6610991933, 'lat': 13.4477334071, 'Drainage_density': 62.0661735534668}
#
# Analizando fila 192/2874
# Coincidencia más cercana encontrada en el índice 16821647: 56.509891510009766
# Datos combinados: {'long': -16.6564819336, 'lat': 13.4477638436, 'Drainage_density': 56.509891510009766}
#
# Analizando fila 193/2874
# Coincidencia más cercana encontrada en el índice 16810727: 57.04884719848633
# Datos combinados: {'long': -16.6518646617, 'lat': 13.4477941955, 'Drainage_density': 57.04884719848633}
#
# Analizando fila 194/2874
# Coincidencia más cercana encontrada en el índice 16810743: 55.27607345581055
# Datos combinados: {'long': -16.6472473783, 'lat': 13.4478244628, 'Drainage_density': 55.27607345581055}
#
# Analizando fila 195/2874
# Coincidencia más cercana encontrada en el índice 16810760: 47.978233337402344
# Datos combinados: {'long': -16.6426300836, 'lat': 13.4478546454, 'Drainage_density': 47.978233337402344}
#
# Analizando fila 196/2874
# Coincidencia más cercana encontrada en el índice 16810777: 42.59401321411133
# Datos combinados: {'long': -16.6380127776, 'lat': 13.4478847435, 'Drainage_density': 42.59401321411133}
#
# Analizando fila 197/2874
# Coincidencia más cercana encontrada en el índice 16810793: 48.03276824951172
# Datos combinados: {'long': -16.6333954604, 'lat': 13.4479147568, 'Drainage_density': 48.03276824951172}
#
# Analizando fila 198/2874
# Coincidencia más cercana encontrada en el índice 16810810: 30.931100845336914
# Datos combinados: {'long': -16.6287781319, 'lat': 13.4479446856, 'Drainage_density': 30.931100845336914}
#
# Analizando fila 199/2874
# Coincidencia más cercana encontrada en el índice 16810826: 25.373865127563477
# Datos combinados: {'long': -16.624160793, 'lat': 13.4479745297, 'Drainage_density': 25.373865127563477}
#
# Analizando fila 200/2874
# Coincidencia más cercana encontrada en el índice 16810843: 25.67518424987793
# Datos combinados: {'long': -16.6195434421, 'lat': 13.4480042892, 'Drainage_density': 25.67518424987793}
#
# Analizando fila 201/2874
# Coincidencia más cercana encontrada en el índice 16810860: 26.941530227661133
# Datos combinados: {'long': -16.61492608, 'lat': 13.448033964, 'Drainage_density': 26.941530227661133}
#
# Analizando fila 202/2874
# Coincidencia más cercana encontrada en el índice 16799939: 27.184843063354492
# Datos combinados: {'long': -16.6103087068, 'lat': 13.4480635542, 'Drainage_density': 27.184843063354492}
#
# Analizando fila 203/2874
# Coincidencia más cercana encontrada en el índice 16799956: 27.184843063354492
# Datos combinados: {'long': -16.6056913225, 'lat': 13.4480930598, 'Drainage_density': 27.184843063354492}
#
# Analizando fila 204/2874
# Coincidencia más cercana encontrada en el índice 16799973: 25.296964645385742
# Datos combinados: {'long': -16.6010739272, 'lat': 13.4481224807, 'Drainage_density': 25.296964645385742}
#
# Analizando fila 205/2874
# Coincidencia más cercana encontrada en el índice 16799989: 26.46007537841797
# Datos combinados: {'long': -16.5964565208, 'lat': 13.448151817, 'Drainage_density': 26.46007537841797}
#
# Analizando fila 206/2874
# Coincidencia más cercana encontrada en el índice 16800006: 22.0139102935791
# Datos combinados: {'long': -16.5918391044, 'lat': 13.4481810686, 'Drainage_density': 22.0139102935791}
#
# Analizando fila 207/2874
# Coincidencia más cercana encontrada en el índice 16800022: 18.52234649658203
# Datos combinados: {'long': -16.587221676, 'lat': 13.4482102356, 'Drainage_density': 18.52234649658203}
#
# Analizando fila 208/2874
# Coincidencia más cercana encontrada en el índice 16800039: 9.231817245483398
# Datos combinados: {'long': -16.5826042368, 'lat': 13.448239318, 'Drainage_density': 9.231817245483398}
#
# Analizando fila 209/2874
# Coincidencia más cercana encontrada en el índice 16800056: 6.131608963012695
# Datos combinados: {'long': -16.5779867866, 'lat': 13.4482683157, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 210/2874
# Coincidencia más cercana encontrada en el índice 16800072: 6.131608963012695
# Datos combinados: {'long': -16.5733693256, 'lat': 13.4482972287, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 211/2874
# Coincidencia más cercana encontrada en el índice 16800089: 6.131608963012695
# Datos combinados: {'long': -16.5687518537, 'lat': 13.4483260571, 'Drainage_density': 6.131608963012695}
#
# Analizando fila 212/2874
# Coincidencia más cercana encontrada en el índice 17007327: 13.805142402648926
# Datos combinados: {'long': -16.7257072797, 'lat': 13.4427792714, 'Drainage_density': 13.805142402648926}
#
# Analizando fila 213/2874
# Coincidencia más cercana encontrada en el índice 17007343: 18.70706558227539
# Datos combinados: {'long': -16.7210902686, 'lat': 13.4428108816, 'Drainage_density': 18.70706558227539}
#
# Analizando fila 214/2874
# Coincidencia más cercana encontrada en el índice 17007360: 36.59248352050781
# Datos combinados: {'long': -16.7164732466, 'lat': 13.4428424073, 'Drainage_density': 36.59248352050781}
#
# Analizando fila 215/2874
# Coincidencia más cercana encontrada en el índice 17007377: 60.356624603271484
# Datos combinados: {'long': -16.7118562118, 'lat': 13.4428738484, 'Drainage_density': 60.356624603271484}
#
# Analizando fila 216/2874
# Coincidencia más cercana encontrada en el índice 17007393: 70.29238891601562
# Datos combinados: {'long': -16.7072391653, 'lat': 13.4429052048, 'Drainage_density': 70.29238891601562}
#
# Analizando fila 217/2874
# Coincidencia más cercana encontrada en el índice 17007410: 72.93144226074219
# Datos combinados: {'long': -16.702622107, 'lat': 13.4429364767, 'Drainage_density': 72.93144226074219}
#
# Analizando fila 218/2874
# Coincidencia más cercana encontrada en el índice 17007427: 74.27822875976562
# Datos combinados: {'long': -16.6980050369, 'lat': 13.442967664, 'Drainage_density': 74.27822875976562}
#
# Analizando fila 219/2874
# Coincidencia más cercana encontrada en el índice 17007443: 75.75159454345703
# Datos combinados: {'long': -16.6933879552, 'lat': 13.4429987668, 'Drainage_density': 75.75159454345703}
#
# Analizando fila 220/2874
# Coincidencia más cercana encontrada en el índice 17007460: 82.36351013183594
# Datos combinados: {'long': -16.6887708618, 'lat': 13.4430297849, 'Drainage_density': 82.36351013183594}
#
# Analizando fila 221/2874
# Coincidencia más cercana encontrada en el índice 16996539: 78.64619445800781
# Datos combinados: {'long': -16.6841537578, 'lat': 13.4430607184, 'Drainage_density': 78.64619445800781}
#
# Analizando fila 222/2874
# Coincidencia más cercana encontrada en el índice 16996556: 91.10313415527344
# Datos combinados: {'long': -16.6795366412, 'lat': 13.4430915673, 'Drainage_density': 91.10313415527344}
#
# Analizando fila 223/2874
# Coincidencia más cercana encontrada en el índice 16996573: 84.84431457519531
# Datos combinados: {'long': -16.674919513, 'lat': 13.4431223317, 'Drainage_density': 84.84431457519531}
#
# Analizando fila 224/2874
# Coincidencia más cercana encontrada en el índice 16996589: 80.73004913330078
# Datos combinados: {'long': -16.6703023733, 'lat': 13.4431530114, 'Drainage_density': 80.73004913330078}
#
# Analizando fila 225/2874
# Coincidencia más cercana encontrada en el índice 16996606: 71.3361587524414
# Datos combinados: {'long': -16.6656852221, 'lat': 13.4431836066, 'Drainage_density': 71.3361587524414}
#
# Analizando fila 226/2874
# Coincidencia más cercana encontrada en el índice 16996623: 60.881229400634766
# Datos combinados: {'long': -16.6610680594, 'lat': 13.4432141171, 'Drainage_density': 60.881229400634766}
#
# Analizando fila 227/2874
# Coincidencia más cercana encontrada en el índice 16996639: 62.252281188964844
# Datos combinados: {'long': -16.6564508862, 'lat': 13.4432445431, 'Drainage_density': 62.252281188964844}
#
# Analizando fila 228/2874
# Coincidencia más cercana encontrada en el índice 16996656: 66.34822845458984
# Datos combinados: {'long': -16.6518337007, 'lat': 13.4432748844, 'Drainage_density': 66.34822845458984}
#
# Analizando fila 229/2874
# Coincidencia más cercana encontrada en el índice 16996672: 64.85579681396484
# Datos combinados: {'long': -16.6472165038, 'lat': 13.4433051411, 'Drainage_density': 64.85579681396484}
#
# Analizando fila 230/2874
# Coincidencia más cercana encontrada en el índice 16985752: 53.67873764038086
# Datos combinados: {'long': -16.6425992956, 'lat': 13.4433353133, 'Drainage_density': 53.67873764038086}
#
# Analizando fila 231/2874
# Coincidencia más cercana encontrada en el índice 16985769: 42.577247619628906
# Datos combinados: {'long': -16.637982076, 'lat': 13.4433654008, 'Drainage_density': 42.577247619628906}
#
# Analizando fila 232/2874
# Coincidencia más cercana encontrada en el índice 16985785: 44.64934158325195
# ...
# Datos combinados: {'long': -16.7602319276, 'lat': 13.1081090284, 'Drainage_density': 27.013492584228516}
#
# Analizando fila 2799/2874
# Coincidencia más cercana encontrada en el índice 30186304: 28.904428482055664
# Datos combinados: {'long': -16.7556213197, 'lat': 13.1081404841, 'Drainage_density': 28.904428482055664}
#
# Analizando fila 2800/2874
# Coincidencia más cercana encontrada en el índice 30186321: 54.93266677856445
# Datos combinados: {'long': -16.7510106998, 'lat': 13.1081718574, 'Drainage_density': 54.93266677856445}
#
# Analizando fila 2801/2874
# Coincidencia más cercana encontrada en el índice 30186337: 70.72323608398438
# Datos combinados: {'long': -16.7464000688, 'lat': 13.1082031483, 'Drainage_density': 70.72323608398438}
#
# Analizando fila 2802/2874
# Coincidencia más cercana encontrada en el índice 30186354: 89.40605926513672
# Datos combinados: {'long': -16.741789425, 'lat': 13.1082343568, 'Drainage_density': 89.40605926513672}
#
# Analizando fila 2803/2874
# Coincidencia más cercana encontrada en el índice 30186371: 96.48931884765625
# Datos combinados: {'long': -16.7371787692, 'lat': 13.1082654829, 'Drainage_density': 96.48931884765625}
#
# Analizando fila 2804/2874
# Coincidencia más cercana encontrada en el índice 30175483: 119.68682098388672
# Datos combinados: {'long': -16.7233467306, 'lat': 13.1083583667, 'Drainage_density': 119.68682098388672}
#
# Analizando fila 2805/2874
# Coincidencia más cercana encontrada en el índice 30372183: 14.634730339050293
# Datos combinados: {'long': -16.7694208109, 'lat': 13.1035267171, 'Drainage_density': 14.634730339050293}
#
# Analizando fila 2806/2874
# Coincidencia más cercana encontrada en el índice 30372200: 17.469425201416016
# Datos combinados: {'long': -16.7648103112, 'lat': 13.1035583264, 'Drainage_density': 17.469425201416016}
#
# Analizando fila 2807/2874
# Coincidencia más cercana encontrada en el índice 30372217: 30.63329315185547
# Datos combinados: {'long': -16.7601997995, 'lat': 13.1035898532, 'Drainage_density': 30.63329315185547}
#
# Analizando fila 2808/2874
# Coincidencia más cercana encontrada en el índice 30361296: 36.83597946166992
# Datos combinados: {'long': -16.7555892757, 'lat': 13.1036212977, 'Drainage_density': 36.83597946166992}
#
# Analizando fila 2809/2874
# Coincidencia más cercana encontrada en el índice 30361313: 64.7394027709961
# Datos combinados: {'long': -16.7509787398, 'lat': 13.1036526598, 'Drainage_density': 64.7394027709961}
#
# Analizando fila 2810/2874
# Coincidencia más cercana encontrada en el índice 30361329: 79.2428970336914
# Datos combinados: {'long': -16.7463681929, 'lat': 13.1036839395, 'Drainage_density': 79.2428970336914}
#
# Analizando fila 2811/2874
# Coincidencia más cercana encontrada en el índice 30361346: 87.1205062866211
# Datos combinados: {'long': -16.7417576331, 'lat': 13.1037151369, 'Drainage_density': 87.1205062866211}
#
# Analizando fila 2812/2874
# Coincidencia más cercana encontrada en el índice 30361363: 92.90394592285156
# Datos combinados: {'long': -16.7371470614, 'lat': 13.1037462519, 'Drainage_density': 92.90394592285156}
#
# Analizando fila 2813/2874
# Coincidencia más cercana encontrada en el índice 30361379: 100.536865234375
# Datos combinados: {'long': -16.7325364777, 'lat': 13.1037772845, 'Drainage_density': 100.536865234375}
#
# Analizando fila 2814/2874
# Coincidencia más cercana encontrada en el índice 30547176: 14.623831748962402
# Datos combinados: {'long': -16.7693885269, 'lat': 13.0990075628, 'Drainage_density': 14.623831748962402}
#
# Analizando fila 2815/2874
# Coincidencia más cercana encontrada en el índice 30547192: 17.338716506958008
# Datos combinados: {'long': -16.7647781112, 'lat': 13.0990391607, 'Drainage_density': 17.338716506958008}
#
# Analizando fila 2816/2874
# Coincidencia más cercana encontrada en el índice 30547209: 30.611364364624023
# Datos combinados: {'long': -16.7601676834, 'lat': 13.0990706763, 'Drainage_density': 30.611364364624023}
#
# Analizando fila 2817/2874
# Coincidencia más cercana encontrada en el índice 30547225: 48.800567626953125
# Datos combinados: {'long': -16.7555572436, 'lat': 13.0991021096, 'Drainage_density': 48.800567626953125}
#
# Analizando fila 2818/2874
# Coincidencia más cercana encontrada en el índice 30547242: 66.57135009765625
# Datos combinados: {'long': -16.7509467918, 'lat': 13.0991334605, 'Drainage_density': 66.57135009765625}
#
# Analizando fila 2819/2874
# Coincidencia más cercana encontrada en el índice 30547259: 79.29682159423828
# Datos combinados: {'long': -16.7463363289, 'lat': 13.0991647291, 'Drainage_density': 79.29682159423828}
#
# Analizando fila 2820/2874
# Coincidencia más cercana encontrada en el índice 30536338: 83.44853210449219
# Datos combinados: {'long': -16.7417258531, 'lat': 13.0991959153, 'Drainage_density': 83.44853210449219}
#
# Analizando fila 2821/2874
# Coincidencia más cercana encontrada en el índice 30536355: 89.48863983154297
# Datos combinados: {'long': -16.7371153654, 'lat': 13.0992270192, 'Drainage_density': 89.48863983154297}
#
# Analizando fila 2822/2874
# Coincidencia más cercana encontrada en el índice 30536371: 98.31023406982422
# Datos combinados: {'long': -16.7325048658, 'lat': 13.0992580408, 'Drainage_density': 98.31023406982422}
#
# Analizando fila 2823/2874
# Coincidencia más cercana encontrada en el índice 30536388: 105.98469543457031
# Datos combinados: {'long': -16.7278943543, 'lat': 13.0992889799, 'Drainage_density': 105.98469543457031}
#
# Analizando fila 2824/2874
# Coincidencia más cercana encontrada en el índice 30536405: 109.40728759765625
# Datos combinados: {'long': -16.723283831, 'lat': 13.0993198368, 'Drainage_density': 109.40728759765625}
#
# Analizando fila 2825/2874
# Coincidencia más cercana encontrada en el índice 30722168: 14.010420799255371
# Datos combinados: {'long': -16.7693562549, 'lat': 13.0944884068, 'Drainage_density': 14.010420799255371}
#
# Analizando fila 2826/2874
# Coincidencia más cercana encontrada en el índice 30722184: 17.447582244873047
# Datos combinados: {'long': -16.7647459232, 'lat': 13.0945199934, 'Drainage_density': 17.447582244873047}
#
# Analizando fila 2827/2874
# Coincidencia más cercana encontrada en el índice 30722201: 30.611650466918945
# Datos combinados: {'long': -16.7601355795, 'lat': 13.0945514978, 'Drainage_density': 30.611650466918945}
#
# Analizando fila 2828/2874
# Coincidencia más cercana encontrada en el índice 30722218: 48.69289779663086
# Datos combinados: {'long': -16.7555252237, 'lat': 13.0945829199, 'Drainage_density': 48.69289779663086}
#
# Analizando fila 2829/2874
# Coincidencia más cercana encontrada en el índice 30722234: 64.39575958251953
# Datos combinados: {'long': -16.7509148558, 'lat': 13.0946142596, 'Drainage_density': 64.39575958251953}
#
# Analizando fila 2830/2874
# Coincidencia más cercana encontrada en el índice 30722251: 73.06485748291016
# Datos combinados: {'long': -16.7463044769, 'lat': 13.094645517, 'Drainage_density': 73.06485748291016}
#
# Analizando fila 2831/2874
# Coincidencia más cercana encontrada en el índice 30722267: 81.72937774658203
# Datos combinados: {'long': -16.7416940851, 'lat': 13.0946766921, 'Drainage_density': 81.72937774658203}
#
# Analizando fila 2832/2874
# Coincidencia más cercana encontrada en el índice 30722284: 84.35327911376953
# Datos combinados: {'long': -16.7370836814, 'lat': 13.0947077849, 'Drainage_density': 84.35327911376953}
#
# Analizando fila 2833/2874
# Coincidencia más cercana encontrada en el índice 30711364: 93.8159408569336
# Datos combinados: {'long': -16.7324732658, 'lat': 13.0947387954, 'Drainage_density': 93.8159408569336}
#
# Analizando fila 2834/2874
# Coincidencia más cercana encontrada en el índice 30711380: 97.1277847290039
# Datos combinados: {'long': -16.7278628383, 'lat': 13.0947697235, 'Drainage_density': 97.1277847290039}
#
# Analizando fila 2835/2874
# Coincidencia más cercana encontrada en el índice 30711397: 98.26319885253906
# Datos combinados: {'long': -16.723252399, 'lat': 13.0948005693, 'Drainage_density': 98.26319885253906}
#
# Analizando fila 2836/2874
# Coincidencia más cercana encontrada en el índice 30908097: 12.691717147827148
# Datos combinados: {'long': -16.7693239951, 'lat': 13.0899692491, 'Drainage_density': 12.691717147827148}
#
# Analizando fila 2837/2874
# Coincidencia más cercana encontrada en el índice 30897176: 17.168498992919922
# Datos combinados: {'long': -16.7647137474, 'lat': 13.0900008245, 'Drainage_density': 17.168498992919922}
#
# Analizando fila 2838/2874
# Coincidencia más cercana encontrada en el índice 30897193: 28.455007553100586
# Datos combinados: {'long': -16.7601034876, 'lat': 13.0900323176, 'Drainage_density': 28.455007553100586}
#
# Analizando fila 2839/2874
# Coincidencia más cercana encontrada en el índice 30897210: 44.319026947021484
# Datos combinados: {'long': -16.7554932157, 'lat': 13.0900637284, 'Drainage_density': 44.319026947021484}
#
# Analizando fila 2840/2874
# Coincidencia más cercana encontrada en el índice 30897226: 53.70692825317383
# Datos combinados: {'long': -16.7508829318, 'lat': 13.090095057, 'Drainage_density': 53.70692825317383}
#
# Analizando fila 2841/2874
# Coincidencia más cercana encontrada en el índice 30897243: 65.66426086425781
# Datos combinados: {'long': -16.7462726368, 'lat': 13.0901263032, 'Drainage_density': 65.66426086425781}
#
# Analizando fila 2842/2874
# Coincidencia más cercana encontrada en el índice 30897259: 77.00452423095703
# Datos combinados: {'long': -16.741662329, 'lat': 13.0901574672, 'Drainage_density': 77.00452423095703}
#
# Analizando fila 2843/2874
# Coincidencia más cercana encontrada en el índice 30897276: 78.19312286376953
# Datos combinados: {'long': -16.7370520092, 'lat': 13.0901885489, 'Drainage_density': 78.19312286376953}
#
# Analizando fila 2844/2874
# Coincidencia más cercana encontrada en el índice 30897293: 82.54824829101562
# Datos combinados: {'long': -16.7324416776, 'lat': 13.0902195483, 'Drainage_density': 82.54824829101562}
#
# Analizando fila 2845/2874
# Coincidencia más cercana encontrada en el índice 31083089: 10.123430252075195
# Datos combinados: {'long': -16.7692917474, 'lat': 13.0854500898, 'Drainage_density': 10.123430252075195}
#
# Analizando fila 2846/2874
# Coincidencia más cercana encontrada en el índice 31083106: 15.076083183288574
# Datos combinados: {'long': -16.7646815836, 'lat': 13.0854816539, 'Drainage_density': 15.076083183288574}
#
# Analizando fila 2847/2874
# Coincidencia más cercana encontrada en el índice 31083122: 23.119070053100586
# Datos combinados: {'long': -16.7600714077, 'lat': 13.0855131358, 'Drainage_density': 23.119070053100586}
#
# Analizando fila 2848/2874
# Coincidencia más cercana encontrada en el índice 31083139: 38.06356430053711
# Datos combinados: {'long': -16.7554612197, 'lat': 13.0855445354, 'Drainage_density': 38.06356430053711}
#
# Analizando fila 2849/2874
# Coincidencia más cercana encontrada en el índice 31072218: 47.19497299194336
# Datos combinados: {'long': -16.7508510198, 'lat': 13.0855758527, 'Drainage_density': 47.19497299194336}
#
# Analizando fila 2850/2874
# Coincidencia más cercana encontrada en el índice 31072235: 58.5012321472168
# Datos combinados: {'long': -16.7462408088, 'lat': 13.0856070878, 'Drainage_density': 58.5012321472168}
#
# Analizando fila 2851/2874
# Coincidencia más cercana encontrada en el índice 31072252: 70.7289047241211
# Datos combinados: {'long': -16.7416305848, 'lat': 13.0856382407, 'Drainage_density': 70.7289047241211}
#
# Analizando fila 2852/2874
# Coincidencia más cercana encontrada en el índice 31072268: 72.63209533691406
# Datos combinados: {'long': -16.737020349, 'lat': 13.0856693113, 'Drainage_density': 72.63209533691406}
#
# Analizando fila 2853/2874
# Coincidencia más cercana encontrada en el índice 31072285: 71.4853515625
# Datos combinados: {'long': -16.7324101013, 'lat': 13.0857002996, 'Drainage_density': 71.4853515625}
#
# Analizando fila 2854/2874
# Coincidencia más cercana encontrada en el índice 31072301: 71.1865005493164
# Datos combinados: {'long': -16.7277998417, 'lat': 13.0857312057, 'Drainage_density': 71.1865005493164}
#
# Analizando fila 2855/2874
# Coincidencia más cercana encontrada en el índice 31258081: 8.441676139831543
# Datos combinados: {'long': -16.7692595118, 'lat': 13.0809309297, 'Drainage_density': 8.441676139831543}
#
# Analizando fila 2856/2874
# Coincidencia más cercana encontrada en el índice 31258098: 13.099637985229492
# Datos combinados: {'long': -16.7646494319, 'lat': 13.0809624825, 'Drainage_density': 13.099637985229492}
#
# Analizando fila 2857/2874
# Coincidencia más cercana encontrada en el índice 31258114: 19.978965759277344
# Datos combinados: {'long': -16.7600393399, 'lat': 13.0809939532, 'Drainage_density': 19.978965759277344}
#
# Analizando fila 2858/2874
# Coincidencia más cercana encontrada en el índice 31258131: 25.070331573486328
# Datos combinados: {'long': -16.7554292358, 'lat': 13.0810253416, 'Drainage_density': 25.070331573486328}
#
# Analizando fila 2859/2874
# Coincidencia más cercana encontrada en el índice 31258147: 40.62397003173828
# Datos combinados: {'long': -16.7508191198, 'lat': 13.0810566477, 'Drainage_density': 40.62397003173828}
#
# Analizando fila 2860/2874
# Coincidencia más cercana encontrada en el índice 31258164: 50.09709930419922
# Datos combinados: {'long': -16.7462089926, 'lat': 13.0810878717, 'Drainage_density': 50.09709930419922}
#
# Analizando fila 2861/2874
# Coincidencia más cercana encontrada en el índice 31247244: 62.30018997192383
# Datos combinados: {'long': -16.7415988526, 'lat': 13.0811190134, 'Drainage_density': 62.30018997192383}
#
# Analizando fila 2862/2874
# Coincidencia más cercana encontrada en el índice 31247260: 66.70237731933594
# Datos combinados: {'long': -16.7369887007, 'lat': 13.0811500729, 'Drainage_density': 66.70237731933594}
#
# Analizando fila 2863/2874
# Coincidencia más cercana encontrada en el índice 31247277: 60.856910705566406
# Datos combinados: {'long': -16.7323785368, 'lat': 13.0811810501, 'Drainage_density': 60.856910705566406}
#
# Analizando fila 2864/2874
# Coincidencia más cercana encontrada en el índice 31247293: 60.46479034423828
# Datos combinados: {'long': -16.7277683611, 'lat': 13.0812119452, 'Drainage_density': 60.46479034423828}
#
# Analizando fila 2865/2874
# Coincidencia más cercana encontrada en el índice 31411199: 7.423830509185791
# Datos combinados: {'long': -16.7692272883, 'lat': 13.076411767, 'Drainage_density': 7.423830509185791}
#
# Analizando fila 2866/2874
# Coincidencia más cercana encontrada en el índice 31411216: 11.146446228027344
# Datos combinados: {'long': -16.7646172923, 'lat': 13.0764433086, 'Drainage_density': 11.146446228027344}
#
# Analizando fila 2867/2874
# Coincidencia más cercana encontrada en el índice 31411232: 17.128068923950195
# Datos combinados: {'long': -16.7600072841, 'lat': 13.076474768, 'Drainage_density': 17.128068923950195}
#
# Analizando fila 2868/2874
# Coincidencia más cercana encontrada en el índice 31411249: 19.67397689819336
# Datos combinados: {'long': -16.7553972639, 'lat': 13.0765061452, 'Drainage_density': 19.67397689819336}
#
# Analizando fila 2869/2874
# Coincidencia más cercana encontrada en el índice 31411266: 25.622915267944336
# Datos combinados: {'long': -16.7507872317, 'lat': 13.0765374402, 'Drainage_density': 25.622915267944336}
#
# Analizando fila 2870/2874
# Coincidencia más cercana encontrada en el índice 31411282: 34.97788619995117
# Datos combinados: {'long': -16.7461771884, 'lat': 13.076568653, 'Drainage_density': 34.97788619995117}
#
# Analizando fila 2871/2874
# Coincidencia más cercana encontrada en el índice 31411299: 44.63280487060547
# Datos combinados: {'long': -16.7415671323, 'lat': 13.0765997835, 'Drainage_density': 44.63280487060547}
#
# Analizando fila 2872/2874
# Coincidencia más cercana encontrada en el índice 31411315: 49.92258834838867
# Datos combinados: {'long': -16.7369570642, 'lat': 13.0766308319, 'Drainage_density': 49.92258834838867}
#
# Analizando fila 2873/2874
# Coincidencia más cercana encontrada en el índice 31411332: 49.457000732421875
# Datos combinados: {'long': -16.7323469842, 'lat': 13.0766617981, 'Drainage_density': 49.457000732421875}
#
# Analizando fila 2874/2874
# Coincidencia más cercana encontrada en el índice 31411349: 48.28218078613281
# Datos combinados: {'long': -16.7277368924, 'lat': 13.0766926821, 'Drainage_density': 48.28218078613281}
